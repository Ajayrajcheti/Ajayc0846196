# %%
# !pip install gym >/dev/null

# %%
# !pip install JSAnimation >/dev/null

# %%
# %matplotlib inline
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
import matplotlib.pyplot as plt
from IPython.display import HTML

def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 144)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames = len(frames), interval=50)
    HTML(anim.to_jshtml())

# %% [markdown]
# ## Step 2: Playing Pong

# %%
# %pip install -U gym>=0.21.0
# %pip install -U gym[atari,accept-rom-license]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gym[accept-rom-license,atari] in /usr/local/lib/python3.7/dist-packages (0.25.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (0.0.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (4.12.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.7/dist-packages (from gym[accept-rom-license,atari]) (1.21.6)
# Collecting ale-py~=0.7.5
#   Downloading ale_py-0.7.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.1 MB/s
# Collecting autorom[accept-rom-license]~=0.4.2
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from ale-py~=0.7.5->gym[accept-rom-license,atari]) (5.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (7.1.2)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.4.2.tar.gz (9.8 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[accept-rom-license,atari]) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.8.0->gym[accept-rom-license,atari]) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gym[accept-rom-license,atari]) (1.24.3)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (PEP 517) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.4.2-py3-none-any.whl size=441027 sha256=1c6ebf12f8eaf317ff774b02170deade6df3b4cda1f51091ff14a9f11953b7a3
#   Stored in directory: /root/.cache/pip/wheels/87/67/2e/6147e7912fe37f5408b80d07527dab807c1d25f5c403a9538a
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom, ale-py
# Successfully installed AutoROM.accept-rom-license-0.4.2 ale-py-0.7.5 autorom-0.4.2

# %%
import gym
env = gym.make('Pong-v0')
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py:594: UserWarning: WARN: The environment Pong-v0 is out of date. You should consider upgrading to version `v4`.
#   f"The environment {id} is out of date. You should consider "
# /usr/local/lib/python3.7/dist-packages/gym/core.py:330: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/step_api_compatibility.py:40: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."

# %%
env.action_space
# Out:
# Discrete(6)

# %%
env.observation_space
# Out:
# Box(0, 255, (210, 160, 3), uint8)

# %%
# Run a demo of the environment
observation = env.reset()
cumulated_reward = 0

frames = []
for t in range(1000):
#     print(observation)
    frames.append(env.render(mode = 'rgb_array'))
    # very stupid agent, just makes a random action within the allowd action space
    action = env.action_space.sample()
#     print("Action: {}".format(t+1))    
    observation, reward, done, info = env.step(action)
#     print(reward)
    cumulated_reward += reward
    if done:
        print("Episode finished after {} timesteps, accumulated reward = {}".format(t+1, cumulated_reward))
        break
print("Episode finished without success, accumulated reward = {}".format(cumulated_reward))

env.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:52: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   "The argument mode in render method is deprecated; "
# /usr/local/lib/python3.7/dist-packages/gym/utils/passive_env_checker.py:298: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   "No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps."
# /usr/local/lib/python3.7/dist-packages/gym/utils/passive_env_checker.py:228: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   "Core environment is written in old step API which returns one bool instead of two. "
# Episode finished without success, accumulated reward = -16.0

# %%
def sigmoid(x): 
  return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

def prepro(I):
  """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
  I = I[35:195] # crop
  I = I[::2,::2,0] # downsample by factor of 2
  I[I == 144] = 0 # erase background (background type 1)
  I[I == 109] = 0 # erase background (background type 2)
  I[I != 0] = 1 # everything else (paddles, ball) just set to 1
  return I.astype(np.float).ravel()

def policy_forward(x):
  h = np.dot(model['W1'], x)
  h[h<0] = 0 # ReLU nonlinearity
  logp = np.dot(model['W2'], h)
  p = sigmoid(logp)
  return p, h # return probability of taking action 2, and hidden state

def model_step(model, observation, prev_x):
  # preprocess the observation, set input to network to be difference image
  cur_x = prepro(observation)
  x = cur_x - prev_x if prev_x is not None else np.zeros(D)
  prev_x = cur_x
  
  # forward the policy network and sample an action from the returned probability
  aprob, _ = policy_forward(x)
  action = 2 if aprob >= 0.5 else 3 # roll the dice!
  
  return action, prev_x

def play_game(env, model):
  observation = env.reset()

  frames = []
  cumulated_reward = 0

  prev_x = None # used in computing the difference frame

  for t in range(1000):
      frames.append(env.render(mode = 'rgb_array'))
      action, prev_x = model_step(model, observation, prev_x)
      observation, reward, done, info = env.step(action)
      cumulated_reward += reward
      if done:
          print("Episode finished after {} timesteps, accumulated reward = {}".format(t+1, cumulated_reward))
          break
  print("Episode finished without success, accumulated reward = {}".format(cumulated_reward))
  display_frames_as_gif(frames)
  env.close()

# %% [markdown]
# ## Step 3: Policy Gradient from Scratch

# %%
import numpy as np

# model initialization
H = 200 # number of hidden layer neurons
D = 80 * 80 # input dimensionality: 80x80 grid
model = {}
model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization
model['W2'] = np.random.randn(H) / np.sqrt(H)

# import pickle
# model = pickle.load(open('model.pkl', 'rb'))

# %%
# hyperparameters
batch_size = 10 # every how many episodes to do a param update?
# learning_rate = 1e-4
learning_rate = 1e-2
 
gamma = 0.99 # discount factor for reward
decay_rate = 0.99 # decay factor for RMSProp leaky sum of grad^2
  
grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

def discount_rewards(r):
  """ take 1D float array of rewards and compute discounted reward """
  discounted_r = np.zeros_like(r, dtype=np.float32)
  running_add = 0
  for t in reversed(range(0, r.size)):
    if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
    running_add = running_add * gamma + r[t]
    discounted_r[t] = running_add
  return discounted_r

def policy_backward(epx, eph, epdlogp):
  """ backward pass. (eph is array of intermediate hidden states) """
  dW2 = np.dot(eph.T, epdlogp).ravel()
  dh = np.outer(epdlogp, model['W2'])
  dh[eph <= 0] = 0 # backpro prelu
  dW1 = np.dot(dh.T, epx)
  return {'W1':dW1, 'W2':dW2}

def train_model(env, model, total_episodes = 100):
  hist = []
  observation = env.reset()

  prev_x = None # used in computing the difference frame
  xs,hs,dlogps,drs = [],[],[],[]
  running_reward = None
  reward_sum = 0
  episode_number = 0

  while True:
    # preprocess the observation, set input to network to be difference image
    cur_x = prepro(observation)
    x = cur_x - prev_x if prev_x is not None else np.zeros(D)
    prev_x = cur_x

    # forward the policy network and sample an action from the returned probability
    aprob, h = policy_forward(x)
    action = 2 if np.random.uniform() < aprob else 3 # roll the dice!

    # record various intermediates (needed later for backprop)
    xs.append(x) # observation
    hs.append(h) # hidden state
    y = 1 if action == 2 else 0 # a "fake label"
    dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

    # step the environment and get new measurements
    observation, reward, done, info = env.step(action)
    reward_sum += reward

    drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

    if done: # an episode finished
      episode_number += 1

      # stack together all inputs, hidden states, action gradients, and rewards for this episode
      epx = np.vstack(xs)
      eph = np.vstack(hs)
      epdlogp = np.vstack(dlogps)
      epr = np.vstack(drs)
      xs,hs,dlogps,drs = [],[],[],[] # reset array memory

      # compute the discounted reward backwards through time
      discounted_epr = discount_rewards(epr)
      # standardize the rewards to be unit normal (helps control the gradient estimator variance)
      discounted_epr -= np.mean(discounted_epr)
      discounted_epr /= np.std(discounted_epr)

      epdlogp *= discounted_epr # modulate the gradient with advantage (PG magic happens right here.)
      grad = policy_backward(epx, eph, epdlogp)
      for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

      # perform rmsprop parameter update every batch_size episodes
      if episode_number % batch_size == 0:
        for k,v in model.items():
          g = grad_buffer[k] # gradient
          rmsprop_cache[k] = decay_rate * rmsprop_cache[k] + (1 - decay_rate) * g**2
          model[k] += learning_rate * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
          grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer

      # boring book-keeping
      running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
      hist.append((episode_number, reward_sum, running_reward))
      print ('resetting env. episode %f, reward total was %f. running mean: %f' % (episode_number, reward_sum, running_reward))
      reward_sum = 0
      observation = env.reset() # reset env
      prev_x = None
      if episode_number == total_episodes: return hist

      if reward != 0: # Pong has either +1 or -1 reward exactly when game ends.
        print (('ep %d: game finished, reward: %f' % (episode_number, reward)) + ('' if reward == -1 else ' !!!!!!!!'))

# %%
# %time hist1 = train_model(env, model, total_episodes=3000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# resetting env. episode 1.000000, reward total was -21.000000. running mean: -21.000000
# resetting env. episode 2.000000, reward total was -21.000000. running mean: -21.000000
# resetting env. episode 3.000000, reward total was -19.000000. running mean: -20.980000
# resetting env. episode 4.000000, reward total was -19.000000. running mean: -20.960200
# resetting env. episode 5.000000, reward total was -21.000000. running mean: -20.960598
# resetting env. episode 6.000000, reward total was -21.000000. running mean: -20.960992
# resetting env. episode 7.000000, reward total was -20.000000. running mean: -20.951382
# resetting env. episode 8.000000, reward total was -21.000000. running mean: -20.951868
# resetting env. episode 9.000000, reward total was -21.000000. running mean: -20.952350
# resetting env. episode 10.000000, reward total was -20.000000. running mean: -20.942826
# resetting env. episode 11.000000, reward total was -18.000000. running mean: -20.913398
# resetting env. episode 12.000000, reward total was -20.000000. running mean: -20.904264
# resetting env. episode 13.000000, reward total was -21.000000. running mean: -20.905221
# resetting env. episode 14.000000, reward total was -21.000000. running mean: -20.906169
# resetting env. episode 15.000000, reward total was -20.000000. running mean: -20.897107
# resetting env. episode 16.000000, reward total was -20.000000. running mean: -20.888136
# resetting env. episode 501.000000, reward total was -21.000000. running mean: -20.998271
# resetting env. episode 502.000000, reward total was -21.000000. running mean: -20.998288
# resetting env. episode 503.000000, reward total was -21.000000. running mean: -20.998305
# resetting env. episode 504.000000, reward total was -21.000000. running mean: -20.998322
# resetting env. episode 505.000000, reward total was -21.000000. running mean: -20.998339
# resetting env. episode 506.000000, reward total was -21.000000. running mean: -20.998355
# resetting env. episode 507.000000, reward total was -21.000000. running mean: -20.998372
# resetting env. episode 508.000000, reward total was -21.000000. running mean: -20.998388
# resetting env. episode 509.000000, reward total was -21.000000. running mean: -20.998404
# resetting env. episode 510.000000, reward total was -21.000000. running mean: -20.998420
# resetting env. episode 511.000000, reward total was -21.000000. running mean: -20.998436
# resetting env. episode 512.000000, reward total was -21.000000. running mean: -20.998452
# resetting env. episode 513.000000, reward total was -21.000000. running mean: -20.998467
# resetting env. episode 514.000000, reward total was -21.000000. running mean: -20.998482
# resetting env. episode 515.000000, reward total was -21.000000. running mean: -20.998498
# resetting env. episode 516.000000, reward total was -21.000000. running mean: -20.998513
# resetting env. episode 517.000000, reward total was -21.000000. running mean: -20.998527
# resetting env. episode 518.000000, reward total was -21.000000. running mean: -20.998542
# resetting env. episode 519.000000, reward total was -21.000000. running mean: -20.998557
# resetting env. episode 520.000000, reward total was -21.000000. running mean: -20.998571
# resetting env. episode 521.000000, reward total was -21.000000. running mean: -20.998585
# resetting env. episode 522.000000, reward total was -21.000000. running mean: -20.998600
# resetting env. episode 523.000000, reward total was -21.000000. running mean: -20.998614
# resetting env. episode 524.000000, reward total was -21.000000. running mean: -20.998627
# resetting env. episode 525.000000, reward total was -21.000000. running mean: -20.998641
# resetting env. episode 526.000000, reward total was -21.000000. running mean: -20.998655
# resetting env. episode 527.000000, reward total was -21.000000. running mean: -20.998668
# resetting env. episode 528.000000, reward total was -21.000000. running mean: -20.998682
# resetting env. episode 529.000000, reward total was -21.000000. running mean: -20.998695
# resetting env. episode 530.000000, reward total was -21.000000. running mean: -20.998708
# resetting env. episode 531.000000, reward total was -21.000000. running mean: -20.998721
# resetting env. episode 532.000000, reward total was -21.000000. running mean: -20.998733
# resetting env. episode 533.000000, reward total was -21.000000. running mean: -20.998746
# resetting env. episode 534.000000, reward total was -21.000000. running mean: -20.998759
# ...
# resetting env. episode 2825.000000, reward total was -21.000000. running mean: -20.999671
# resetting env. episode 2826.000000, reward total was -21.000000. running mean: -20.999675
# resetting env. episode 2827.000000, reward total was -21.000000. running mean: -20.999678
# resetting env. episode 2828.000000, reward total was -21.000000. running mean: -20.999681
# resetting env. episode 2829.000000, reward total was -21.000000. running mean: -20.999684
# resetting env. episode 2830.000000, reward total was -21.000000. running mean: -20.999687
# resetting env. episode 2831.000000, reward total was -21.000000. running mean: -20.999690
# resetting env. episode 2832.000000, reward total was -21.000000. running mean: -20.999694
# resetting env. episode 2833.000000, reward total was -21.000000. running mean: -20.999697
# resetting env. episode 2834.000000, reward total was -21.000000. running mean: -20.999700
# resetting env. episode 2835.000000, reward total was -21.000000. running mean: -20.999703
# resetting env. episode 2836.000000, reward total was -21.000000. running mean: -20.999706
# resetting env. episode 2837.000000, reward total was -21.000000. running mean: -20.999709
# resetting env. episode 2838.000000, reward total was -21.000000. running mean: -20.999712
# resetting env. episode 2839.000000, reward total was -21.000000. running mean: -20.999714
# resetting env. episode 2840.000000, reward total was -21.000000. running mean: -20.999717
# resetting env. episode 2841.000000, reward total was -21.000000. running mean: -20.999720
# resetting env. episode 2842.000000, reward total was -21.000000. running mean: -20.999723
# resetting env. episode 2843.000000, reward total was -21.000000. running mean: -20.999726
# resetting env. episode 2844.000000, reward total was -21.000000. running mean: -20.999728
# resetting env. episode 2845.000000, reward total was -21.000000. running mean: -20.999731
# resetting env. episode 2846.000000, reward total was -21.000000. running mean: -20.999734
# resetting env. episode 2847.000000, reward total was -21.000000. running mean: -20.999736
# resetting env. episode 2848.000000, reward total was -21.000000. running mean: -20.999739
# resetting env. episode 2849.000000, reward total was -21.000000. running mean: -20.999742
# resetting env. episode 2850.000000, reward total was -21.000000. running mean: -20.999744
# resetting env. episode 2851.000000, reward total was -21.000000. running mean: -20.999747
# resetting env. episode 2852.000000, reward total was -21.000000. running mean: -20.999749
# resetting env. episode 2853.000000, reward total was -21.000000. running mean: -20.999752
# resetting env. episode 2854.000000, reward total was -21.000000. running mean: -20.999754
# resetting env. episode 2855.000000, reward total was -21.000000. running mean: -20.999757
# resetting env. episode 2856.000000, reward total was -21.000000. running mean: -20.999759
# resetting env. episode 2857.000000, reward total was -21.000000. running mean: -20.999762
# resetting env. episode 2858.000000, reward total was -21.000000. running mean: -20.999764
# resetting env. episode 2859.000000, reward total was -21.000000. running mean: -20.999766
# resetting env. episode 2860.000000, reward total was -21.000000. running mean: -20.999769
# resetting env. episode 2861.000000, reward total was -21.000000. running mean: -20.999771
# resetting env. episode 2862.000000, reward total was -21.000000. running mean: -20.999773
# resetting env. episode 2863.000000, reward total was -21.000000. running mean: -20.999776
# resetting env. episode 2864.000000, reward total was -21.000000. running mean: -20.999778
# resetting env. episode 2865.000000, reward total was -21.000000. running mean: -20.999780
# resetting env. episode 2866.000000, reward total was -21.000000. running mean: -20.999782
# resetting env. episode 2867.000000, reward total was -21.000000. running mean: -20.999784
# resetting env. episode 2868.000000, reward total was -21.000000. running mean: -20.999787
# resetting env. episode 2869.000000, reward total was -21.000000. running mean: -20.999789
# resetting env. episode 2870.000000, reward total was -21.000000. running mean: -20.999791
# resetting env. episode 2871.000000, reward total was -21.000000. running mean: -20.999793
# resetting env. episode 2872.000000, reward total was -21.000000. running mean: -20.999795
# resetting env. episode 2873.000000, reward total was -21.000000. running mean: -20.999797
# resetting env. episode 2874.000000, reward total was -21.000000. running mean: -20.999799
# resetting env. episode 2875.000000, reward total was -21.000000. running mean: -20.999801
# resetting env. episode 2876.000000, reward total was -21.000000. running mean: -20.999803
# resetting env. episode 2877.000000, reward total was -21.000000. running mean: -20.999805
# resetting env. episode 2878.000000, reward total was -21.000000. running mean: -20.999807
# resetting env. episode 2879.000000, reward total was -21.000000. running mean: -20.999809
# resetting env. episode 2880.000000, reward total was -21.000000. running mean: -20.999811
# resetting env. episode 2881.000000, reward total was -21.000000. running mean: -20.999813
# resetting env. episode 2882.000000, reward total was -21.000000. running mean: -20.999815
# resetting env. episode 2883.000000, reward total was -21.000000. running mean: -20.999816
# resetting env. episode 2884.000000, reward total was -21.000000. running mean: -20.999818
# resetting env. episode 2885.000000, reward total was -21.000000. running mean: -20.999820
# resetting env. episode 2886.000000, reward total was -21.000000. running mean: -20.999822
# resetting env. episode 2887.000000, reward total was -21.000000. running mean: -20.999824
# resetting env. episode 2888.000000, reward total was -21.000000. running mean: -20.999825
# resetting env. episode 2889.000000, reward total was -21.000000. running mean: -20.999827
# resetting env. episode 2890.000000, reward total was -21.000000. running mean: -20.999829
# resetting env. episode 2891.000000, reward total was -21.000000. running mean: -20.999831
# resetting env. episode 2892.000000, reward total was -21.000000. running mean: -20.999832
# resetting env. episode 2893.000000, reward total was -21.000000. running mean: -20.999834
# resetting env. episode 2894.000000, reward total was -21.000000. running mean: -20.999836
# resetting env. episode 2895.000000, reward total was -21.000000. running mean: -20.999837
# resetting env. episode 2896.000000, reward total was -21.000000. running mean: -20.999839
# resetting env. episode 2897.000000, reward total was -21.000000. running mean: -20.999841
# resetting env. episode 2898.000000, reward total was -21.000000. running mean: -20.999842
# resetting env. episode 2899.000000, reward total was -21.000000. running mean: -20.999844
# resetting env. episode 2900.000000, reward total was -21.000000. running mean: -20.999845
# resetting env. episode 2901.000000, reward total was -21.000000. running mean: -20.999847
# resetting env. episode 2902.000000, reward total was -21.000000. running mean: -20.999848
# resetting env. episode 2903.000000, reward total was -21.000000. running mean: -20.999850
# resetting env. episode 2904.000000, reward total was -21.000000. running mean: -20.999851
# resetting env. episode 2905.000000, reward total was -21.000000. running mean: -20.999853
# resetting env. episode 2906.000000, reward total was -21.000000. running mean: -20.999854
# resetting env. episode 2907.000000, reward total was -21.000000. running mean: -20.999856
# resetting env. episode 2908.000000, reward total was -21.000000. running mean: -20.999857
# resetting env. episode 2909.000000, reward total was -21.000000. running mean: -20.999859
# resetting env. episode 2910.000000, reward total was -21.000000. running mean: -20.999860
# resetting env. episode 2911.000000, reward total was -21.000000. running mean: -20.999861
# resetting env. episode 2912.000000, reward total was -21.000000. running mean: -20.999863
# resetting env. episode 2913.000000, reward total was -21.000000. running mean: -20.999864
# resetting env. episode 2914.000000, reward total was -21.000000. running mean: -20.999866
# resetting env. episode 2915.000000, reward total was -21.000000. running mean: -20.999867
# resetting env. episode 2916.000000, reward total was -21.000000. running mean: -20.999868
# resetting env. episode 2917.000000, reward total was -21.000000. running mean: -20.999870
# resetting env. episode 2918.000000, reward total was -21.000000. running mean: -20.999871
# resetting env. episode 2919.000000, reward total was -21.000000. running mean: -20.999872
# resetting env. episode 2920.000000, reward total was -21.000000. running mean: -20.999873
# resetting env. episode 2921.000000, reward total was -21.000000. running mean: -20.999875
# resetting env. episode 2922.000000, reward total was -21.000000. running mean: -20.999876
# resetting env. episode 2923.000000, reward total was -21.000000. running mean: -20.999877
# resetting env. episode 2924.000000, reward total was -21.000000. running mean: -20.999878
# resetting env. episode 2925.000000, reward total was -21.000000. running mean: -20.999880
# resetting env. episode 2926.000000, reward total was -21.000000. running mean: -20.999881
# resetting env. episode 2927.000000, reward total was -21.000000. running mean: -20.999882
# resetting env. episode 2928.000000, reward total was -21.000000. running mean: -20.999883
# resetting env. episode 2929.000000, reward total was -21.000000. running mean: -20.999884
# resetting env. episode 2930.000000, reward total was -21.000000. running mean: -20.999886
# resetting env. episode 2931.000000, reward total was -21.000000. running mean: -20.999887
# resetting env. episode 2932.000000, reward total was -21.000000. running mean: -20.999888
# resetting env. episode 2933.000000, reward total was -21.000000. running mean: -20.999889
# resetting env. episode 2934.000000, reward total was -21.000000. running mean: -20.999890
# resetting env. episode 2935.000000, reward total was -21.000000. running mean: -20.999891
# resetting env. episode 2936.000000, reward total was -21.000000. running mean: -20.999892
# resetting env. episode 2937.000000, reward total was -21.000000. running mean: -20.999893
# resetting env. episode 2938.000000, reward total was -21.000000. running mean: -20.999894
# resetting env. episode 2939.000000, reward total was -21.000000. running mean: -20.999895
# resetting env. episode 2940.000000, reward total was -21.000000. running mean: -20.999897
# resetting env. episode 2941.000000, reward total was -21.000000. running mean: -20.999898
# resetting env. episode 2942.000000, reward total was -21.000000. running mean: -20.999899
# resetting env. episode 2943.000000, reward total was -21.000000. running mean: -20.999900
# resetting env. episode 2944.000000, reward total was -21.000000. running mean: -20.999901
# resetting env. episode 2945.000000, reward total was -21.000000. running mean: -20.999902
# resetting env. episode 2946.000000, reward total was -21.000000. running mean: -20.999903
# resetting env. episode 2947.000000, reward total was -21.000000. running mean: -20.999904
# resetting env. episode 2948.000000, reward total was -21.000000. running mean: -20.999904
# resetting env. episode 2949.000000, reward total was -21.000000. running mean: -20.999905
# resetting env. episode 2950.000000, reward total was -21.000000. running mean: -20.999906
# resetting env. episode 2951.000000, reward total was -21.000000. running mean: -20.999907
# resetting env. episode 2952.000000, reward total was -21.000000. running mean: -20.999908
# resetting env. episode 2953.000000, reward total was -21.000000. running mean: -20.999909
# resetting env. episode 2954.000000, reward total was -21.000000. running mean: -20.999910
# resetting env. episode 2955.000000, reward total was -21.000000. running mean: -20.999911
# resetting env. episode 2956.000000, reward total was -21.000000. running mean: -20.999912
# resetting env. episode 2957.000000, reward total was -21.000000. running mean: -20.999913
# resetting env. episode 2958.000000, reward total was -21.000000. running mean: -20.999914
# resetting env. episode 2959.000000, reward total was -21.000000. running mean: -20.999914
# resetting env. episode 2960.000000, reward total was -21.000000. running mean: -20.999915
# resetting env. episode 2961.000000, reward total was -21.000000. running mean: -20.999916
# resetting env. episode 2962.000000, reward total was -21.000000. running mean: -20.999917
# resetting env. episode 2963.000000, reward total was -21.000000. running mean: -20.999918
# resetting env. episode 2964.000000, reward total was -21.000000. running mean: -20.999919
# resetting env. episode 2965.000000, reward total was -21.000000. running mean: -20.999919
# resetting env. episode 2966.000000, reward total was -21.000000. running mean: -20.999920
# resetting env. episode 2967.000000, reward total was -21.000000. running mean: -20.999921
# resetting env. episode 2968.000000, reward total was -21.000000. running mean: -20.999922
# resetting env. episode 2969.000000, reward total was -21.000000. running mean: -20.999923
# resetting env. episode 2970.000000, reward total was -21.000000. running mean: -20.999923
# resetting env. episode 2971.000000, reward total was -21.000000. running mean: -20.999924
# resetting env. episode 2972.000000, reward total was -21.000000. running mean: -20.999925
# resetting env. episode 2973.000000, reward total was -21.000000. running mean: -20.999926
# resetting env. episode 2974.000000, reward total was -21.000000. running mean: -20.999926
# resetting env. episode 2975.000000, reward total was -21.000000. running mean: -20.999927
# resetting env. episode 2976.000000, reward total was -21.000000. running mean: -20.999928
# resetting env. episode 2977.000000, reward total was -21.000000. running mean: -20.999929
# resetting env. episode 2978.000000, reward total was -21.000000. running mean: -20.999929
# resetting env. episode 2979.000000, reward total was -21.000000. running mean: -20.999930
# resetting env. episode 2980.000000, reward total was -21.000000. running mean: -20.999931
# resetting env. episode 2981.000000, reward total was -21.000000. running mean: -20.999931
# resetting env. episode 2982.000000, reward total was -21.000000. running mean: -20.999932
# resetting env. episode 2983.000000, reward total was -21.000000. running mean: -20.999933
# resetting env. episode 2984.000000, reward total was -21.000000. running mean: -20.999933
# resetting env. episode 2985.000000, reward total was -21.000000. running mean: -20.999934
# resetting env. episode 2986.000000, reward total was -21.000000. running mean: -20.999935
# resetting env. episode 2987.000000, reward total was -21.000000. running mean: -20.999935
# resetting env. episode 2988.000000, reward total was -21.000000. running mean: -20.999936
# resetting env. episode 2989.000000, reward total was -21.000000. running mean: -20.999937
# resetting env. episode 2990.000000, reward total was -21.000000. running mean: -20.999937
# resetting env. episode 2991.000000, reward total was -21.000000. running mean: -20.999938
# resetting env. episode 2992.000000, reward total was -21.000000. running mean: -20.999939
# resetting env. episode 2993.000000, reward total was -21.000000. running mean: -20.999939
# resetting env. episode 2994.000000, reward total was -21.000000. running mean: -20.999940
# resetting env. episode 2995.000000, reward total was -21.000000. running mean: -20.999940
# resetting env. episode 2996.000000, reward total was -21.000000. running mean: -20.999941
# resetting env. episode 2997.000000, reward total was -21.000000. running mean: -20.999942
# resetting env. episode 2998.000000, reward total was -21.000000. running mean: -20.999942
# resetting env. episode 2999.000000, reward total was -21.000000. running mean: -20.999943
# resetting env. episode 3000.000000, reward total was -21.000000. running mean: -20.999943
# CPU times: user 1h 50min 57s, sys: 49min 59s, total: 2h 40min 56s
# Wall time: 1h 22min 24s

# %%
#%time hist2 = train_model(env, model, total_episodes=500)

# %%
play_game(env, model)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# Episode finished without success, accumulated reward = -19.0

# %%
#%time hist3 = train_model(env, model, total_episodes=1500)

# %%
#play_game(env, model)
